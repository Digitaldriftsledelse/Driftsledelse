# %% [markdown]
# # 1.Portfolio problematik

# %% [markdown]
# ##1.4 Forekomst / delmængder

# %% [markdown]
# ### 1.4.1 Angiv udvælgelseskriterier

# %% [markdown]
# Installere bibliotek til at konverter pdf filer

# %%
# !pip install tabula-py

# %% [markdown]
# Importer pandas

# %%
import pandas as pd

# %% [markdown]
# Angiv stien av pdf

# %%
import tabula

df = ("https://www.frukt.no/globalassets/materiell/totaloversikten/frukt--og-grontstatistikk-2019-m-aktive-linker-rettet32.pdf")
output = "test.csv"

# %% [markdown]
# ### 1.4.2 Vælg tabeller / filer af interesse

# %% [markdown]
# Konventere pdf til csv

# %%
tabula.convert_into(df, output, output_format="csv", stream=True, pages='all')
